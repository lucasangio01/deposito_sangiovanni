# %%
from lez2_2 import *

# %%
data = load_data(path = "../data/Wholesale customers data.csv")

# %%
data.head()
# Out:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0  12669  9656     7561     214              2674        1338
# 1   7057  9810     9568    1762              3293        1776
# 2   6353  8808     7684    2405              3516        7844
# 3  13265  1196     4221    6404               507        1788
# 4  22615  5410     7198    3915              1777        5185

# %%
data_scaled = scale_data(data)

# %%
data_scaled_pca = apply_pca(data_scaled)

# %%
choose_min_samples(data_scaled_pca)

# %%
silhouette_avg = compute_silhouette_avg(data_scaled_pca) # min_samples = 5
print(round(silhouette_avg, 3))
# Out:
# 0.761

# %%
plot_dbscan(data_scaled, make_dbscan(data_scaled_pca, min_samples=5))
